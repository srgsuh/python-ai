# %%
import numpy as np

# %%
docs = np.array([
    [0.3, -1.2, 0.4, 0.9],
    [-0.9, 2.1, 0.7, -1.0],
    [0.5, -0.1, 0.1, 0.8],
    [1.5, 2.9, -1.7, -2.2]
])
rk = np.linalg.matrix_rank(docs)
rk
# Out:
# np.int64(4)

# %%
query = np.array([0.6, -1.5, 0.3, 0.2])
v = np.array([1, -1, 1, -1])

dot_prod = np.vdot(query, v)
norm_query = np.vdot(query, query)
norm_v = np.vdot(v, v)
cs = dot_prod / (norm_query * norm_v)

dot_prod, norm_query, norm_v, cs
# Out:
# (np.float64(2.1999999999999997),
#  np.float64(2.7399999999999998),
#  np.int64(4),
#  np.float64(0.20072992700729927))

# %%
q_norm = query / np.linalg.norm(query)
q_norm
# Out:
# array([ 0.36247326, -0.90618314,  0.18123663,  0.12082442])

# %%
docs_lenghts = np.linalg.norm(docs, axis=1, keepdims=True)
docs_lengths
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 docs_lenghts = np.linalg.norm(docs, axis=1, keepdims=True)
# ----> 2 docs_lengths
#
# NameError: name 'docs_lengths' is not defined
