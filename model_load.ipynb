# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import joblib
import converter as conv

# %%
model = joblib.load('gender_pred_model.pkl')

# %%
df = pd.read_csv('car_sales_cleaned1.csv')
df = df.drop_duplicates()
df = df.dropna()
mapper = conv.columnsMapper(['Model', 'Transmission', 'Color'], df)

# %%
p1 = model.predict([[mapper['Model']['Celica'], mapper['Transmission']['Manual'], mapper['Color']['Pale White']]])
p1
# Out:
# C:\Users\ageres\miniconda3\envs\ai_env\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Male'], dtype=object)

# %%
p2 = model.predict([[mapper['Model']['Sonata'], mapper['Transmission']['Manual'], mapper['Color']['Pale White']]])
p2
# Out:
# C:\Users\ageres\miniconda3\envs\ai_env\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Male'], dtype=object)
