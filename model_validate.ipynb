# %%
from ultralytics.models import YOLO
import matplotlib.pyplot as plt
model = YOLO("./runs/detect/circle_exp/weights/best.pt")
results = model("datasets/val/images/img01.jpg")
annotated = results[0].plot()
plt.imshow(annotated)
plt.show()
# Out:
# image 1/1 c:\Users\ageres\WebstormProjects\__backend\python-ai\datasets\val\images\img01.jpg: 256x256 1 circle, 99.1ms
# Speed: 0.8ms preprocess, 99.1ms inference, 3.7ms postprocess per image at shape (1, 3, 256, 256)
