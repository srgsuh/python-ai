# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

h, w = 100, 100
img1 = np.zeros((w, h, 3), dtype=np.uint8)

#for y in range(h):
#    for x in range(w):
#        if y == x:
#            img1[y, x, 0] = 255

plt.imshow(img1)
plt.show()

# %%
cv2.line(img1, (0, 0), (w - 1, h - 1), (255, 0, 0))
cv2.line(img1, (w - 1, 0), (0, h - 1), (255, 0, 0))
plt.imshow(img1)
plt.show()

# %%
img2 = np.random.randint(0, 256, (100, 100, 3), dtype=np.uint8)
plt.imshow(img2)
plt.show()

# %%
img2 = np.random.randint(0, 256, (50, 50), dtype=np.uint8)
plt.axis('off')
plt.imshow(img2, cmap='summer')
plt.show()

# %%
values = np.array([3, 5, 1, 7, 0, 9, 0, 11], dtype = np.uint8)
plt.plot(values)
plt.title("Simple line")
plt.show()

# %%
background = np.full((100, 100), 128, dtype=np.uint8)
plt.imshow(background, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
import time
from IPython.display import clear_output, display

img4 = np.full((30, 30), 255, dtype=np.uint8)
for t in range(20):
    for r in range(30):
        for c in range(30):
            img4[r, c] = 0 if np.random.randint(0, 2) else 220
    display(plt.gcf())
    clear_output(wait=True)
    time.sleep(1)
    
plt.imshow(img4, cmap='gray', vmin=0, vmax=255)
plt.show()
