# %%
text = "I want to find a job in the IT field. I’m studying programming at Tel-Ran courses. \
The instructors say I need to do my homework if I want to get hired. \
But because of family responsibilities and other commitments, I can’t find the time for it."

# %%
from text_sklearn_model import TextModel

model = TextModel(text)

# %%
questions = [
    "What do the instructors say?",
    "What are you studying at the courses?"
]
answers = {q: model.getAnswers(q, 1) for q in questions}
answers
# Out:
# {'What do the instructors say?': ['The instructors say I need to do my homework if I want to get hired'],
#  'What are you studying at the courses?': ['I’m studying programming at Tel-Ran courses']}
