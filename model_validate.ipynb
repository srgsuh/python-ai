# %%
from ultralytics.models import YOLO
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
model1 = YOLO("./runs/detect/circle_rect/weights/best.pt")
results = model1(["img/rect_and_circle.jpg",
                  "img/circle.jpg", 
                  "img/bubbles.jpg", 
                  "img/doors.jpg",
                  "img/rectangles.jpg",
                  "img/glass.jpg",
                  "img/shapes.jpg",
                  "img/pavement.jpg"])
images = [r.plot() for r in results]
len(images)
# Out:
# 0: 256x256 1 circle, 1 rectangle, 45.8ms
# 1: 256x256 1 circle, 45.8ms
# 2: 256x256 1 circle, 45.8ms
# 3: 256x256 1 rectangle, 45.8ms
# 4: 256x256 1 rectangle, 45.8ms
# 5: 256x256 1 circle, 45.8ms
# 6: 256x256 1 circle, 45.8ms
# 7: 256x256 (no detections), 45.8ms
# Speed: 2.7ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 256)
# 8

# %%
plt.imshow(images[0])
plt.show()

# %%
plt.imshow(images[1])
plt.show()

# %%
plt.imshow(images[2])
plt.show()

# %%
plt.imshow(images[3])
plt.show()

# %%
plt.imshow(images[4])
plt.show()

# %%
plt.imshow(images[5])
plt.show()

# %%
plt.imshow(images[6])
plt.show()

# %%
plt.imshow(images[7])
plt.show()
